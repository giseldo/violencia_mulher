# %% [markdown]
# <a href="https://colab.research.google.com/github/giseldo/violencia_mulher/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/dados_corrigido_2015.csv')

# %%
df.head()
# Out:
#     ANO  UF  REGIAO  SEXO  IDADE  ESC  RENDA  RACACOR  P04  P05  ...  P24  \
# 0  2015  11       3     2      1    2      1        4    2    2  ...
# 1  2015  11       3     2      2    1      1        2    2    2  ...
# 2  2015  11       3     2      2    3      1        4    1    1  ...
# 3  2015  11       3     2      3    2      1        1    2    1  ...
# 4  2015  11       3     2      3    2      2        4    2    1  ...
#
#    P25  P26  P27  P28  P29 P30 P31 LIXO             PESO
# 0                                   NaN  947233504124293
# 1                                   NaN  947233504124293
# 2                                   NaN  947233504124293
# 3                                   NaN  947233504124293
# 4                                   NaN  947233504124293
#
# [5 rows x 71 columns]

# %%
colunas_apagar = ['P04', 'P05', 'P06', 'P071', 'P072', 'P073', 'P074', 'P08',
 'P091', 'P092', 'P093', 'P094', 'P095', 'P096', 'P097', 'P098',
 'P099', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16',
 'P17', 'P181', 'P182', 'P183', 'P184', 'P185', 'P186', 'P187',
 'P2001', 'P2002', 'P2003', 'P2004', 'P2005', 'P2006', 'P2007', 'P2008',
 'P2009', 'P2010', 'P2011', 'P211', 'P212', 'P213', 'P214', 'P215',
 'P216', 'P217', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 
 'P28', 'P29', 'P30', 'P31', 'PESO', 'SEXO', 'ANO', 'LIXO']
df = df.drop(colunas_apagar, axis=1)

# %%
df.head()
# Out:
#    UF  REGIAO  IDADE  ESC  RENDA  RACACOR  P19
# 0  11       3      1    2      1        4    2
# 1  11       3      2    1      1        2    2
# 2  11       3      2    3      1        4    2
# 3  11       3      3    2      1        1    2
# 4  11       3      3    2      2        4    2

# %%
df.describe().T
# Out:
#           count       mean       std   min   25%   50%   75%   max
# UF       1102.0  32.235027  9.293974  11.0  26.0  33.0  35.0  53.0
# REGIAO   1102.0   2.182396  1.312394   1.0   1.0   2.0   3.0   5.0
# IDADE    1102.0   3.558984  1.500731   1.0   2.0   3.0   5.0   7.0
# ESC      1102.0   2.096189  0.756326   1.0   2.0   2.0   3.0   4.0
# RENDA    1102.0   2.588929  1.245076   1.0   2.0   2.0   3.0   6.0
# RACACOR  1102.0   2.218693  1.442918   1.0   1.0   1.0   4.0   6.0

# %%
df["P19"] = df["P19"].astype(str)
value_count = df["P19"].value_counts()
plt.bar(value_count.index, value_count.values, color=['red', 'blue', 'orange'])
plt.xlabel('Categoria (1 - SIM, 2-NÃO)')
plt.ylabel('Contagem')
plt.title('Contagem de mulheres que sofreram violência.')
plt.show()
